# %% [markdown]
# ### Data Analysis for Diwali Sales DAta
#
# #### Stepes in Data Analysis
#
# >Objective Draw MeaningFull insightes And Valuable Information for  Forcecating(future prediction) andDission Making  For Bussion Growth
#
# >Data Collection - tabular Format(rows,colouns)
#
# >>Data Cleaning
#
# >>EDA(Exp;otary Dat a Analysis)
#
# >>Visualisation (chartes) and key information
#
# >>Conclusion : Report,ppt

# %%
# !pip install numpy pandas
# Out:
# Access is denied.

# %%
#import libraries or modules
import numpy as np
import pandas as pd

# %%
#import dataset
df=pd.read_csv("Diwali Sales Data.csv",encoding= 'unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing & Apparel       2655
# Food                     2493
# Electronics & Gadgets    2087
# Footwear & Shoes         1064
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 353
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                      100
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df['Cust_name'].str.strip('[0-9]')
# Out:
# 0          Sanskriti
# 1             Kartik
# 2              Bindu
# 3             Sudevi
# 4               Joni
#             ...
# 11246        Manning
# 11247    Reichenbach
# 11248          Oshin
# 11249         Noonan
# 11250        Brumley
# Name: Cust_name, Length: 11251, dtype: object

# %%
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
## view null rowes

f1 = df['Amount'].isna()
df[f1]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
f2 = df['Product_Category']=="Auto"
df[f2]
# Out:
#       User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0     1002903  Sanskriti  P00125942      F     26-35   28               0
# 1     1000732     Kartik  P00110942      F     26-35   35               1
# 2     1001990      Bindu  P00118542      F     26-35   35               1
# 3     1001425     Sudevi  P00237842      M      0-17   16               0
# 4     1000588       Joni  P00057942      M     26-35   28               1
# ...       ...        ...        ...    ...       ...  ...             ...
# 2460  1001941      Gopal  P00259142      M     36-45   26               1
# 2461  1001202    Diwakar  P00277642      F     36-45   39               0
# 4588  1005642     Eplett  P00057542      F      0-17   13               0
# 4651  1004704    Manshul  P00085242      F     18-25   24               1
# 4687  1000157   Michelle  P00102042      F     36-45   41               1
#
#                State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount, Status, unnamed1]
# Index: []

# %%
#drop the columns
df.drop(columns=['Status','unnamed1'],inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# >> *Done with unwanted coles and rowes which has any null

# %% [markdown]
# #### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
## Type castinmg of columns
# Amount 
df['Amount'].astype('int32')
# Out:
# Series([], Name: Amount, dtype: int32)

# %%
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [User_ID, Cust_name, Product_ID, Gender, Age Group, Age, Marital_Status, State, Zone, Occupation, Product_Category, Orders, Amount]
# Index: []>

# %%
# to view the Stastitical information 
df.describe()[['Age','Marital_Status','Orders','Amount']]
# Out:
#                 Age  Marital_Status        Orders        Amount
# count  11251.000000    11251.000000  11251.000000  11239.000000
# mean      35.421207        0.420318      2.489290   9453.610858
# std       12.754122        0.493632      1.115047   5222.355869
# min       12.000000        0.000000      1.000000    188.000000
# 25%       27.000000        0.000000      1.500000   5443.000000
# 50%       33.000000        0.000000      2.000000   8109.000000
# 75%       43.000000        1.000000      3.000000  12675.000000
# max       92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# ### FInd out Number of male  and female Custoumers

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7842
# M    3409
# Name: count, dtype: int64

# %% [markdown]
# > importing visulaisation libraris

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install matplotlib
# Out:
# Access is denied.

# %%
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
sns.countplot(x = 'Gender',data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
ax = sns.countplot(x = 'Gender',data = df)

# %%
ax = sns.countplot(x = 'Gender',data = df)
for bar in list(ax.containers):
    ax.bar_label(bar)
